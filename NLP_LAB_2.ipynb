# %% [markdown]
# <a href="https://colab.research.google.com/github/vadhan123/NLP/blob/main/NLP_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
medical_corpus = """Hypertension is a common chronic condition that increases the risk of heart disease and stroke.
Patients with diabetes are advised to monitor their blood glucose levels regularly.
The physician prescribed antibiotics to treat the bacterial infection.
Vaccination helps prevent infectious diseases in vulnerable populations.
The patient reported chest pain and shortness of breath during physical activity."""

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
word_tokenize(medical_corpus)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Hypertension',
#  'is',
#  'a',
#  'common',
#  'chronic',
#  'condition',
#  'that',
#  'increases',
#  'the',
#  'risk',
#  'of',
#  'heart',
#  'disease',
#  'and',
#  'stroke',
#  '.',
#  'Patients',
#  'with',
#  'diabetes',
#  'are',
#  'advised',
#  'to',
#  'monitor',
#  'their',
#  'blood',
#  'glucose',
#  'levels',
#  'regularly',
#  '.',
#  'The',
#  'physician',
#  'prescribed',
#  'antibiotics',
#  'to',
#  'treat',
#  'the',
#  'bacterial',
#  'infection',
#  '.',
#  'Vaccination',
#  'helps',
#  'prevent',
#  'infectious',
#  'diseases',
#  'in',
#  'vulnerable',
#  'populations',
#  '.',
#  'The',
#  'patient',
#  'reported',
#  'chest',
#  'pain',
#  'and',
#  'shortness',
#  'of',
#  'breath',
#  'during',
#  'physical',
#  'activity',
#  '.']

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(medical_corpus)
# Out:
# ['Hypertension is a common chronic condition that increases the risk of heart disease and stroke.',
#  'Patients with diabetes are advised to monitor their blood glucose levels regularly.',
#  'The physician prescribed antibiotics to treat the bacterial infection.',
#  'Vaccination helps prevent infectious diseases in vulnerable populations.',
#  'The patient reported chest pain and shortness of breath during physical activity.']

# %% [markdown]
#   FILTERNING STOP WORDS

# %%
word_in_quote = word_tokenize(medical_corpus)
word_in_quote
# Out:
# ['Hypertension',
#  'is',
#  'a',
#  'common',
#  'chronic',
#  'condition',
#  'that',
#  'increases',
#  'the',
#  'risk',
#  'of',
#  'heart',
#  'disease',
#  'and',
#  'stroke',
#  '.',
#  'Patients',
#  'with',
#  'diabetes',
#  'are',
#  'advised',
#  'to',
#  'monitor',
#  'their',
#  'blood',
#  'glucose',
#  'levels',
#  'regularly',
#  '.',
#  'The',
#  'physician',
#  'prescribed',
#  'antibiotics',
#  'to',
#  'treat',
#  'the',
#  'bacterial',
#  'infection',
#  '.',
#  'Vaccination',
#  'helps',
#  'prevent',
#  'infectious',
#  'diseases',
#  'in',
#  'vulnerable',
#  'populations',
#  '.',
#  'The',
#  'patient',
#  'reported',
#  'chest',
#  'pain',
#  'and',
#  'shortness',
#  'of',
#  'breath',
#  'during',
#  'physical',
#  'activity',
#  '.']

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
filtered_list=[]
for word in word_in_quote:
  if word.casefold() not in stop_words:
    filtered_list.append(word)
filtered_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['Hypertension',
#  'common',
#  'chronic',
#  'condition',
#  'increases',
#  'risk',
#  'heart',
#  'disease',
#  'stroke',
#  '.',
#  'Patients',
#  'diabetes',
#  'advised',
#  'monitor',
#  'blood',
#  'glucose',
#  'levels',
#  'regularly',
#  '.',
#  'physician',
#  'prescribed',
#  'antibiotics',
#  'treat',
#  'bacterial',
#  'infection',
#  '.',
#  'Vaccination',
#  'helps',
#  'prevent',
#  'infectious',
#  'diseases',
#  'vulnerable',
#  'populations',
#  '.',
#  'patient',
#  'reported',
#  'chest',
#  'pain',
#  'shortness',
#  'breath',
#  'physical',
#  'activity',
#  '.']

# %% [markdown]
# STEMMING

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()
words=word_tokenize(medical_corpus)
stemmed_words=[stemmer.stem(word) for word in words]
stemmed_words
# Out:
# ['hypertens',
#  'is',
#  'a',
#  'common',
#  'chronic',
#  'condit',
#  'that',
#  'increas',
#  'the',
#  'risk',
#  'of',
#  'heart',
#  'diseas',
#  'and',
#  'stroke',
#  '.',
#  'patient',
#  'with',
#  'diabet',
#  'are',
#  'advis',
#  'to',
#  'monitor',
#  'their',
#  'blood',
#  'glucos',
#  'level',
#  'regularli',
#  '.',
#  'the',
#  'physician',
#  'prescrib',
#  'antibiot',
#  'to',
#  'treat',
#  'the',
#  'bacteri',
#  'infect',
#  '.',
#  'vaccin',
#  'help',
#  'prevent',
#  'infecti',
#  'diseas',
#  'in',
#  'vulner',
#  'popul',
#  '.',
#  'the',
#  'patient',
#  'report',
#  'chest',
#  'pain',
#  'and',
#  'short',
#  'of',
#  'breath',
#  'dure',
#  'physic',
#  'activ',
#  '.']

# %% [markdown]
#   LEMMATIZATION

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
words = word_tokenize(medical_corpus)
for word in words:
  print(word,"--->",lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Hypertension ---> Hypertension
# is ---> is
# a ---> a
# common ---> common
# chronic ---> chronic
# condition ---> condition
# that ---> that
# increases ---> increase
# the ---> the
# risk ---> risk
# of ---> of
# heart ---> heart
# disease ---> disease
# and ---> and
# stroke ---> stroke
# . ---> .
# Patients ---> Patients
# with ---> with
# diabetes ---> diabetes
# are ---> are
# advised ---> advised
# to ---> to
# monitor ---> monitor
# their ---> their
# blood ---> blood
# glucose ---> glucose
# levels ---> level
# regularly ---> regularly
# . ---> .
# The ---> The
# physician ---> physician
# prescribed ---> prescribed
# antibiotics ---> antibiotic
# to ---> to
# treat ---> treat
# the ---> the
# bacterial ---> bacterial
# infection ---> infection
# . ---> .
# Vaccination ---> Vaccination
# ...

# %% [markdown]
# COMPARISON

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import PorterStemmer,SnowballStemmer,LancasterStemmer,RegexpStemmer,WordNetLemmatizer
porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer(language='english')
regexp = RegexpStemmer('ing|s|e|able',min=4)
lemmatizer = WordNetLemmatizer()
word_list = ["friend", "friendship", "friends", "friendships"]
print("{0:20}{1:20}{2:20}{3:30}{4:40}{5:50}".format("Word","Porter Stemmer","Snowball Stemmer","Lancaster Stemmer",'Regexp Stemmer','WordNetLemmatizer'))
for word in word_list:
    print("{0:20}{1:20}{2:20}{3:30}{4:40}{5:50}".format(word,porter.stem(word),snowball.stem(word),lancaster.stem(word),regexp.stem(word),lemmatizer.lemmatize(word)))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Word                Porter Stemmer      Snowball Stemmer    Lancaster Stemmer             Regexp Stemmer                          WordNetLemmatizer
# friend              friend              friend              friend                        frind                                   friend
# friendship          friendship          friendship          friend                        frindhip                                friendship
# friends             friend              friend              friend                        frind                                   friend
# friendships         friendship          friendship          friend                        frindhip                                friendship
