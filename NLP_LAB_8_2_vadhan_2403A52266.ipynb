# %% [markdown]
# <a href="https://colab.research.google.com/github/vadhan123/NLP/blob/main/NLP_LAB_8_2_vadhan_2403A52266.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab 8.2: N-Gram Language Model Implementation and Evaluation

# %% [markdown]
# CORPUS

# %%
D1 = "Machine learning is a field of artificial intelligence that focuses on building smart systems."

D2 = "Deep learning is a subset of machine learning that uses neural networks."

D3 = "Natural language processing helps computers understand human language."

D4 = "Text mining and data mining are important techniques in data science."

D5 = "Python is widely used for machine learning and data analysis."

D6 = "Big data technologies help in storing and processing large datasets."

D7 = "Artificial intelligence is transforming healthcare and education sectors."

D8 = "Neural networks consist of input layers hidden layers and output layers."

D9 = "Supervised learning and unsupervised learning are types of machine learning."

D10 = "N gram models are used in text analysis and language modeling."

# %% [markdown]
# UNIGRAM COUNTS

# %%
import collections
D1 = "Machine learning is a field of artificial intelligence that focuses on building smart systems."

D2 = "Deep learning is a subset of machine learning that uses neural networks."

D3 = "Natural language processing helps computers understand human language."

D4 = "Text mining and data mining are important techniques in data science."

D5 = "Python is widely used for machine learning and data analysis."

D6 = "Big data technologies help in storing and processing large datasets."

D7 = "Artificial intelligence is transforming healthcare and education sectors."

D8 = "Neural networks consist of input layers hidden layers and output layers."

D9 = "Supervised learning and unsupervised learning are types of machine learning."

D10 = "N gram models are used in text analysis and language modeling."

D1_content = "Machine learning is a field of artificial intelligence that focuses on building smart systems."
D2_content =  "Deep learning is a subset of machine learning that uses neural networks."
D3_content = "Natural language processing helps computers understand human language."
D4_content = "Text mining and data mining are important techniques in data science."
D5_content = "Python is widely used for machine learning and data analysis."
D6_content = "Big data technologies help in storing and processing large datasets."
D7_content = "Artificial intelligence is transforming healthcare and education sectors."
D8_content = "Neural networks consist of input layers hidden layers and output layers."
D9_content = "Supervised learning and unsupervised learning are types of machine learning."
D10_content = "N gram models are used in text analysis and language modeling."

combine_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content} "
word = combine_text.split()
unigram_counts = collections.Counter(word)
print("unigram_counts:")
for worrd, count in unigram_counts.items():
    print(f"{worrd}: {count}")
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# unigram_counts:
# Machine: 1
# learning: 6
# is: 4
# a: 2
# field: 1
# of: 4
# artificial: 1
# intelligence: 2
# that: 2
# focuses: 1
# on: 1
# building: 1
# smart: 1
# systems.: 1
# Deep: 1
# subset: 1
# machine: 3
# uses: 1
# neural: 1
# networks.: 1
# Natural: 1
# language: 2
# processing: 2
# helps: 1
# computers: 1
# understand: 1
# human: 1
# language.: 1
# Text: 1
# mining: 2
# and: 7
# data: 4
# are: 3
# important: 1
# techniques: 1
# in: 3
# science.: 1
# Python: 1
# widely: 1
# used: 2
# for: 1
# analysis.: 1
# Big: 1
# technologies: 1
# help: 1
# storing: 1
# large: 1
# datasets.: 1
# Artificial: 1
# transforming: 1
# healthcare: 1
# education: 1
# sectors.: 1
# Neural: 1
# networks: 1
# consist: 1
# input: 1
# layers: 2
# hidden: 1
# output: 1
# layers.: 1
# Supervised: 1
# unsupervised: 1
# types: 1
# learning.: 1
# N: 1
# gram: 1
# models: 1
# text: 1
# analysis: 1
# modeling.: 1
# Vocabulary Size= 71

# %% [markdown]
# BI-GRAM COUNTS

# %%
import collections
combined_text= f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content} "
words = combined_text.lower().split()
bigram=[]
for i in range(len(words)-1):
  bigram.append((words[i],words[i+1]))
bigram_counts = collections.Counter(bigram)
print("\nbigram_counts:")
for bigram, count in bigram_counts.items():
  print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# bigram_counts:
# machine learning: 3
# learning is: 2
# is a: 2
# a field: 1
# field of: 1
# of artificial: 1
# artificial intelligence: 2
# intelligence that: 1
# that focuses: 1
# focuses on: 1
# on building: 1
# building smart: 1
# smart systems.: 1
# systems. deep: 1
# deep learning: 1
# a subset: 1
# subset of: 1
# of machine: 2
# learning that: 1
# that uses: 1
# uses neural: 1
# neural networks.: 1
# networks. natural: 1
# natural language: 1
# language processing: 1
# processing helps: 1
# helps computers: 1
# computers understand: 1
# understand human: 1
# human language.: 1
# language. text: 1
# text mining: 1
# mining and: 1
# and data: 2
# data mining: 1
# mining are: 1
# are important: 1
# important techniques: 1
# techniques in: 1
# in data: 1
# data science.: 1
# science. python: 1
# python is: 1
# is widely: 1
# widely used: 1
# used for: 1
# for machine: 1
# learning and: 2
# data analysis.: 1
# analysis. big: 1
# big data: 1
# data technologies: 1
# technologies help: 1
# help in: 1
# in storing: 1
# storing and: 1
# and processing: 1
# processing large: 1
# large datasets.: 1
# datasets. artificial: 1
# intelligence is: 1
# is transforming: 1
# transforming healthcare: 1
# healthcare and: 1
# and education: 1
# education sectors.: 1
# sectors. neural: 1
# neural networks: 1
# networks consist: 1
# consist of: 1
# of input: 1
# input layers: 1
# layers hidden: 1
# hidden layers: 1
# layers and: 1
# and output: 1
# output layers.: 1
# layers. supervised: 1
# supervised learning: 1
# and unsupervised: 1
# unsupervised learning: 1
# learning are: 1
# are types: 1
# types of: 1
# machine learning.: 1
# learning. n: 1
# n gram: 1
# gram models: 1
# models are: 1
# are used: 1
# used in: 1
# in text: 1
# text analysis: 1
# analysis and: 1
# and language: 1
# language modeling.: 1

# %% [markdown]
# TRI-GRAM COUNTS

# %%
import collections
words = combined_text.lower().split()
trigram = []
for i in range(len(words) - 2):
    trigram.append((words[i], words[i+1], words[i+2]))
trigram_counts = collections.Counter(trigram)
print("\ntrigram_counts:")
for trigram, count in trigram_counts.items():
    print(f"{trigram[0]} {trigram[1]} {trigram[2]}: {count}")
# Out:
# trigram_counts:
# machine learning is: 1
# learning is a: 2
# is a field: 1
# a field of: 1
# field of artificial: 1
# of artificial intelligence: 1
# artificial intelligence that: 1
# intelligence that focuses: 1
# that focuses on: 1
# focuses on building: 1
# on building smart: 1
# building smart systems.: 1
# smart systems. deep: 1
# systems. deep learning: 1
# deep learning is: 1
# is a subset: 1
# a subset of: 1
# subset of machine: 1
# of machine learning: 1
# machine learning that: 1
# learning that uses: 1
# that uses neural: 1
# uses neural networks.: 1
# neural networks. natural: 1
# networks. natural language: 1
# natural language processing: 1
# language processing helps: 1
# processing helps computers: 1
# helps computers understand: 1
# computers understand human: 1
# understand human language.: 1
# human language. text: 1
# language. text mining: 1
# text mining and: 1
# mining and data: 1
# and data mining: 1
# data mining are: 1
# mining are important: 1
# are important techniques: 1
# important techniques in: 1
# techniques in data: 1
# in data science.: 1
# data science. python: 1
# science. python is: 1
# python is widely: 1
# is widely used: 1
# widely used for: 1
# used for machine: 1
# for machine learning: 1
# machine learning and: 1
# learning and data: 1
# and data analysis.: 1
# data analysis. big: 1
# analysis. big data: 1
# big data technologies: 1
# data technologies help: 1
# technologies help in: 1
# help in storing: 1
# in storing and: 1
# storing and processing: 1
# and processing large: 1
# processing large datasets.: 1
# large datasets. artificial: 1
# datasets. artificial intelligence: 1
# artificial intelligence is: 1
# intelligence is transforming: 1
# is transforming healthcare: 1
# transforming healthcare and: 1
# healthcare and education: 1
# and education sectors.: 1
# education sectors. neural: 1
# sectors. neural networks: 1
# neural networks consist: 1
# networks consist of: 1
# consist of input: 1
# of input layers: 1
# input layers hidden: 1
# layers hidden layers: 1
# hidden layers and: 1
# layers and output: 1
# and output layers.: 1
# output layers. supervised: 1
# layers. supervised learning: 1
# supervised learning and: 1
# learning and unsupervised: 1
# and unsupervised learning: 1
# unsupervised learning are: 1
# learning are types: 1
# are types of: 1
# types of machine: 1
# of machine learning.: 1
# machine learning. n: 1
# learning. n gram: 1
# n gram models: 1
# gram models are: 1
# models are used: 1
# are used in: 1
# used in text: 1
# in text analysis: 1
# text analysis and: 1
# analysis and language: 1
# and language modeling.: 1

# %% [markdown]
# NEXT WORRD PREDICTION USING BI-GRAM COUNTS

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    print(f"\nPredictions for sequence: '{word_sequence}' (last word: '{last_word}')")
    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("  probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "learning is"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "learning that"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "learning and"
next_word3 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "learning are"
next_word4 = predict_next_word_bigram(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# Predictions for sequence: 'learning is' (last word: 'is')
#   probability of  a is  0.5
#   probability of  widely is  0.25
#   probability of  transforming is  0.25
# Given sequence: 'learning is', predicted next word: 'a'
#
# Predictions for sequence: 'learning that' (last word: 'that')
#   probability of  focuses is  0.5
#   probability of  uses is  0.5
# Given sequence: 'learning that', predicted next word: 'focuses'
#
# Predictions for sequence: 'learning and' (last word: 'and')
#   probability of  data is  0.2857142857142857
#   probability of  processing is  0.14285714285714285
#   probability of  education is  0.14285714285714285
#   probability of  output is  0.14285714285714285
#   probability of  unsupervised is  0.14285714285714285
#   probability of  language is  0.14285714285714285
# Given sequence: 'learning and', predicted next word: 'data'
#
# Predictions for sequence: 'learning are' (last word: 'are')
#   probability of  important is  0.3333333333333333
#   probability of  types is  0.3333333333333333
#   probability of  used is  0.3333333333333333
# Given sequence: 'learning are', predicted next word: 'important'

# %% [markdown]
# DEPLOYMENT OF BI-GRAM MODEL

# %%
ip_text=input("enter text")
next_word1= predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text},predicted next word: '{next_word1}")
# Out:
# enter textlearning is
#
# Predictions for sequence: 'learning is' (last word: 'is')
#   probability of  a is  0.5
#   probability of  widely is  0.25
#   probability of  transforming is  0.25
# Given sequence: 'learning is,predicted next word: 'a

# %% [markdown]
# NEXT WORD PREDICTION USING TRI-GRAM COUNT

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."
    last_two_words_tuple = tuple(words_in_sequence[-2:])
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

# Ensure 'trigram_counts' from cell 'cyYA4SkQWr6J' and 'bigram_counts' from cell '_JVLpdVOUZMp' are defined by running those cells first.
sequence1 = "artificial intelligence"
next_word1 = predict_next_word_trigram(sequence1, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "Machine learning is"
next_word2 = predict_next_word_trigram(sequence2, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  that is  0.5
# probability of  is is  0.5
# Given sequence: 'artificial intelligence', predicted next word: 'that'
# probability of  a is  1.0
# Given sequence: 'Machine learning is', predicted next word: 'a'

# %% [markdown]
# DEPLOYMENT OF TRI-GRAM MODEL

# %%
ip_text_trigram = input("Enter a sequence of two words (e.g., 'artificial intelligence'): ")
next_word_trigram = predict_next_word_trigram(ip_text_trigram, trigram_counts, bigram_counts)
print(f"Given sequence: '{ip_text_trigram}', predicted next word: '{next_word_trigram}'")
# Out:
# Enter a sequence of two words (e.g., 'artificial intelligence'): deep learning
# probability of  is is  1.0
# Given sequence: 'deep learning', predicted next word: 'is'

# %% [markdown]
# NEXT WORD PREDICTION USING BI-GRAM COUNTS WITH LAPLACE SMOOTHENING

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
sequence1 = "meachine learning is"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "Natural language processing"
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "and processing "
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = " processing large "
next_word4 = predict_next_word_bigram_Laplace(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of a is  0.04
# probability of widely is  0.02666666666666667
# probability of transforming is  0.02666666666666667
# Given sequence: 'meachine learning is', predicted next word: 'a'
# probability of helps is  0.0273972602739726
# probability of large is  0.0273972602739726
# Given sequence: 'Natural language processing', predicted next word: 'helps'
# probability of helps is  0.0273972602739726
# probability of large is  0.0273972602739726
# Given sequence: 'and processing ', predicted next word: 'helps'
# probability of datasets. is  0.027777777777777776
# Given sequence: ' processing large ', predicted next word: 'datasets.'

# %% [markdown]
# DEPLOYMENT OF LAPLACE SMOOTHENING BASED BI-GRAM MODEL

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textlanguage processing
# probability of helps is  0.0273972602739726
# probability of large is  0.0273972602739726
# Given sequence: 'language processing', predicted next word: 'helps'

# %% [markdown]
# NEXT WORD PREDICTION USING TRI-GRAM COUNTS BASED ON LAPLACE SMOOTHENING

# %%
def predict_next_word_trigram_Laplace(word_sequence, Trigrams_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."
    last_two_words_tuple = tuple(words_in_sequence[-2:])
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+1) / (last_two_words_bigram_count+V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
sequence1 = "a field of "
next_word1 = predict_next_word_trigram_Laplace(sequence1, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "data mining are"
next_word2 = predict_next_word_trigram_Laplace(sequence2, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  artificial is  0.027777777777777776
# Given sequence: 'a field of ', predicted next word: 'artificial'
# probability of  important is  0.027777777777777776
# Given sequence: 'data mining are', predicted next word: 'important'

# %% [markdown]
# DEPLOYMENT OF LAPLACE SMOOTHENING BASED TRI-GRAM MODEL

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_Laplace(ip_text, trigram_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textused in text
# probability of  analysis is  0.027777777777777776
# Given sequence: 'used in text', predicted next word: 'analysis'

# %% [markdown]
# NEXT WORD PREDICTION USING BI-GRAM COUNTS WITH ADD -K SMOOTHENING

# %%
def predict_next_word_bigram_K(word_sequence, bigram_counts, unigram_counts, K):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+K) / (last_word_unigram_count+K*V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "a subset"
next_word1 = predict_next_word_bigram_K(sequence1, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "machine learning "
next_word2 = predict_next_word_bigram_K(sequence2, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "Natural language"
next_word3 = predict_next_word_bigram_K(sequence3, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "widely used "
next_word4 = predict_next_word_bigram_K(sequence4, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of of is  0.0410958904109589
# Given sequence: 'a subset', predicted next word: 'of'
# probability of is is  0.060240963855421686
# probability of that is  0.03614457831325301
# probability of and is  0.060240963855421686
# probability of are is  0.03614457831325301
# Given sequence: 'machine learning ', predicted next word: 'is'
# probability of processing is  0.04
# probability of modeling. is  0.04
# Given sequence: 'Natural language', predicted next word: 'processing'
# probability of for is  0.04
# probability of in is  0.04
# Given sequence: 'widely used ', predicted next word: 'for'

# %% [markdown]
# DEPLOYMENT OF ADD-K SMOOTHENING BASED BI-GRAM MODEL

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_K(ip_text, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textneural networks
# probability of consist is  0.0410958904109589
# Given sequence: 'neural networks', predicted next word: 'consist'

# %% [markdown]
# NEXT WORD PREDICTION USING TRI-GRAM COUNTS WITH ADD-K SMOOTHENING

# %%
def predict_next_word_trigram_K(word_sequence, Trigrams_counts, bigram_counts,K):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    last_two_words_tuple = tuple(words_in_sequence[-2:])

    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+K) / (last_two_words_bigram_count+K*V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word


sequence1 = " for machine learning"
next_word1 = predict_next_word_trigram_K(sequence1, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "learning are types "
next_word2 = predict_next_word_trigram_K(sequence2, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  is is  0.03896103896103896
# probability of  that is  0.03896103896103896
# probability of  and is  0.03896103896103896
# Given sequence: ' for machine learning', predicted next word: 'is'
# probability of  of is  0.0410958904109589
# Given sequence: 'learning are types ', predicted next word: 'of'

# %% [markdown]
# DEPLOYMENT OF ADD-K SMOOTHENING BASED TRI-GRAN MODEL

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_K(ip_text, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textfor machine learning
# probability of  is is  0.03896103896103896
# probability of  that is  0.03896103896103896
# probability of  and is  0.03896103896103896
# Given sequence: 'for machine learning ', predicted next word: 'is'
