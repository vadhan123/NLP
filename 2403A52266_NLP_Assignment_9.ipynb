# %% [markdown]
# <a href="https://colab.research.google.com/github/vadhan123/NLP/blob/main/2403A52266_NLP_Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INSTALL GENSIM IMPORT LIBRARIES

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 21.3 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
from gensim.models import keyedvectors
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

# %% [markdown]
# Load Word2Vec and find numerical vector representation of words

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors

# Load pre-trained Word2Vec model (may take time on first download)
model = api.load("word2vec-google-news-300")

# Print vocabulary size
print("Vocabulary Size:", len(model.key_to_index))

# Display vector for a sample word
word = "king"
vector = model[word]

print("\nWord:", word);
print("Vector length:", len(vector));
print("First 10 values of the vector:\n", vector[:10])
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Vocabulary Size: 3000000
#
# Word: king
# Vector length: 300
# First 10 values of the vector:
#  [ 0.12597656  0.02978516  0.00860596  0.13964844 -0.02563477 -0.03613281
#   0.11181641 -0.19824219  0.05126953  0.36328125]

# %% [markdown]
# Load Glove and find numerical vector representation of words

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-100")
print("Vocabulary Size:", len(model.key_to_index))
word = "king"
vector = model[word]

print("\nWord:", word)
print("Vector length:", len(vector))
print("First 10 values of the vector:\n", vector[:10])
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Vocabulary Size: 400000
#
# Word: king
# Vector length: 100
# First 10 values of the vector:
#  [-0.32307 -0.87616  0.21977  0.25268  0.22976  0.7388  -0.37954 -0.35307
#  -0.84369 -1.1113 ]

# %% [markdown]
# Word Similarity with Word2Vec

# %%
# Define 10 word pairs
word_pairs = [
    ("king", "queen"),
    ("man", "woman"),
    ("boy", "girl"),
    ("cat", "dog"),
    ("apple", "orange"),
    ("car", "automobile"),
    ("good", "bad"),
    ("happy", "joyful"),
    ("fast", "quick"),
    ("tree", "forest")
]

print("Word Similarity Scores (Word2Vec):\n")

for word1, word2 in word_pairs:
    if word1 in model and word2 in model:
        similarity = model.similarity(word1, word2)
        print(f"Similarity between '{word1}' and '{word2}': {similarity:.4f}")
    else:
        print(f"One or both words ('{word1}', '{word2}') not found in vocabulary.")
# Out:
# Word Similarity Scores (Word2Vec):
#
# Similarity between 'king' and 'queen': 0.7508
# Similarity between 'man' and 'woman': 0.8323
# Similarity between 'boy' and 'girl': 0.9176
# Similarity between 'cat' and 'dog': 0.8798
# Similarity between 'apple' and 'orange': 0.5007
# Similarity between 'car' and 'automobile': 0.6832
# Similarity between 'good' and 'bad': 0.7703
# Similarity between 'happy' and 'joyful': 0.5260
# Similarity between 'fast' and 'quick': 0.7107
# Similarity between 'tree' and 'forest': 0.5961

# %% [markdown]
# Word Similarity with GloVe

# %%
# Assuming the 'model' object (GloVe) is already loaded from previous cells.

# Define 10 word pairs
word_pairs = [
    ("king", "queen"),
    ("man", "woman"),
    ("boy", "girl"),
    ("cat", "dog"),
    ("apple", "orange"),
    ("car", "automobile"),
    ("good", "bad"),
    ("happy", "joyful"),
    ("fast", "quick"),
    ("tree", "forest")
]

print("Word Similarity Scores (GloVe):\n")

for word1, word2 in word_pairs:
    if word1 in model and word2 in model:
        similarity = model.similarity(word1, word2)
        print(f"Similarity between '{word1}' and '{word2}': {similarity:.4f}")
    else:
        print(f"One or both words ('{word1}', '{word2}') not found in vocabulary.")
# Out:
# Word Similarity Scores (GloVe):
#
# Similarity between 'king' and 'queen': 0.7508
# Similarity between 'man' and 'woman': 0.8323
# Similarity between 'boy' and 'girl': 0.9176
# Similarity between 'cat' and 'dog': 0.8798
# Similarity between 'apple' and 'orange': 0.5007
# Similarity between 'car' and 'automobile': 0.6832
# Similarity between 'good' and 'bad': 0.7703
# Similarity between 'happy' and 'joyful': 0.5260
# Similarity between 'fast' and 'quick': 0.7107
# Similarity between 'tree' and 'forest': 0.5961

# %% [markdown]
# Load Word2Vec and complete Neighbour words

# %%
# Assuming the 'model' object (Word2Vec) is already loaded from previous cells.

# Define a list of words for which to find nearest neighbors
words_to_find_neighbors = ["king", "woman", "dog", "car", "joyful"]

print("Nearest Neighbors (Word2Vec):\n")

for word in words_to_find_neighbors:
    if word in model:
        # Find the top 5 most similar words for the current word
        similar_words = model.most_similar(word, topn=5)
        print(f"Top 5 nearest neighbors for '{word}':")
        for similar_word, similarity in similar_words:
            print(f"  - {similar_word}: {similarity:.4f}")
        print()
    else:
        print(f"'{word}' not found in Word2Vec vocabulary.\n")
# Out:
# Nearest Neighbors (Word2Vec):
#
# Top 5 nearest neighbors for 'king':
#   - prince: 0.7682
#   - queen: 0.7508
#   - son: 0.7021
#   - brother: 0.6986
#   - monarch: 0.6978
#
# Top 5 nearest neighbors for 'woman':
#   - girl: 0.8473
#   - man: 0.8323
#   - mother: 0.8276
#   - boy: 0.7721
#   - she: 0.7632
#
# Top 5 nearest neighbors for 'dog':
#   - cat: 0.8798
#   - dogs: 0.8344
#   - pet: 0.7450
#   - puppy: 0.7236
#   - horse: 0.7110
#
# Top 5 nearest neighbors for 'car':
#   - vehicle: 0.8631
#   - truck: 0.8598
#   - cars: 0.8372
#   - driver: 0.8186
#   - driving: 0.7813
#
# Top 5 nearest neighbors for 'joyful':
#   - joyous: 0.8993
#   - ecstatic: 0.7422
#   - exuberant: 0.7177
#   - sorrowful: 0.7083
#   - euphoric: 0.7037

# %% [markdown]
# Load Glove and complete Neighbour words

# %%
# Assuming the 'model' object (GloVe) is already loaded from previous cells.

# Define a list of words for which to find nearest neighbors
words_to_find_neighbors_glove = ["king", "woman", "dog", "car", "joyful"]

print("Nearest Neighbors (GloVe):\n")

for word in words_to_find_neighbors_glove:
    if word in model:
        # Find the top 5 most similar words for the current word using GloVe
        similar_words_glove = model.most_similar(word, topn=5)
        print(f"Top 5 nearest neighbors for '{word}' (GloVe):")
        for similar_word_glove, similarity_glove in similar_words_glove:
            print(f"  - {similar_word_glove}: {similarity_glove:.4f}")
        print()
    else:
        print(f"'{word}' not found in GloVe vocabulary.\n")
# Out:
# Nearest Neighbors (GloVe):
#
# Top 5 nearest neighbors for 'king' (GloVe):
#   - prince: 0.7682
#   - queen: 0.7508
#   - son: 0.7021
#   - brother: 0.6986
#   - monarch: 0.6978
#
# Top 5 nearest neighbors for 'woman' (GloVe):
#   - girl: 0.8473
#   - man: 0.8323
#   - mother: 0.8276
#   - boy: 0.7721
#   - she: 0.7632
#
# Top 5 nearest neighbors for 'dog' (GloVe):
#   - cat: 0.8798
#   - dogs: 0.8344
#   - pet: 0.7450
#   - puppy: 0.7236
#   - horse: 0.7110
#
# Top 5 nearest neighbors for 'car' (GloVe):
#   - vehicle: 0.8631
#   - truck: 0.8598
#   - cars: 0.8372
#   - driver: 0.8186
#   - driving: 0.7813
#
# Top 5 nearest neighbors for 'joyful' (GloVe):
#   - joyous: 0.8993
#   - ecstatic: 0.7422
#   - exuberant: 0.7177
#   - sorrowful: 0.7083
#   - euphoric: 0.7037

# %% [markdown]
# Word Analogy with Word2Vec

# %%
import gensim.downloader as api

# Ensure the correct Word2Vec model is loaded, if not already in the kernel state.
# If `model` from the previous Word2Vec loading step is not available,
# or if the kernel restarts, uncomment the line below:
model = api.load("word2vec-google-news-300")

# Analogy 1: King - man + woman = queen
result1 = model.most_similar(
    positive=["king", "woman"],
    negative=["man"],
    topn=5
)

# Analogy 2: Paris - France + India = ? (Capital analogy)
result2 = model.most_similar(
    positive=["paris", "india"],
    negative=["france"],
    topn=5
)

# Analogy 3: Doctor - hospital + school = ? (Profession/Location analogy)
result3 = model.most_similar(
    positive=["doctor", "school"],
    negative=["hospital"],
    topn=5
)
print("\n--- Word Analogies with Word2Vec ---")

print("\nking - man + woman = ?")
print(result1)

print("\nparis - france + india = ?")
print(result2)

print("\ndoctor - hospital + school = ?")
print(result3)
# Out:
# --- Word Analogies with Word2Vec ---
#
# king - man + woman = ?
# [('queen', 0.7118193507194519), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321839332581)]
#
# paris - france + india = ?
# [('chennai', 0.5442505478858948), ('delhi', 0.5149926543235779), ('mumbai', 0.5024341344833374), ('hyderabad', 0.49932485818862915), ('gujarat', 0.48732805252075195)]
#
# doctor - hospital + school = ?
# [('guidance_counselor', 0.5969594717025757), ('teacher', 0.5755364298820496), ('eighth_grade', 0.5226408243179321), ('schoolers', 0.5168290138244629), ('elementary', 0.5085657238960266)]

# %% [markdown]
# Load Glove and complete word analogy

# %%
import gensim.downloader as api

# Ensure the correct GloVe model is loaded, if not already in the kernel state.
# If `model` from the previous GloVe loading step is not available,
# or if the kernel restarts, uncomment the line below:
model = api.load("glove-wiki-gigaword-100")

# Analogy 1: King - man + woman = ?
result1 = model.most_similar(
    positive=["king", "woman"],
    negative=["man"],
    topn=5
)

# Analogy 2: Paris - France + India = ? (Capital analogy)
result2 = model.most_similar(
    positive=["paris", "india"],
    negative=["france"],
    topn=5
)

# Analogy 3: Doctor - hospital + school = ? (Profession/Location analogy)
result3 = model.most_similar(
    positive=["doctor", "school"],
    negative=["hospital"],
    topn=5
)

print("\n--- Word Analogies with GloVe ---")

print("\nking - man + woman = ?")
print(result1)

print("\nparis - france + india = ?")
print(result2)

print("\ndoctor - hospital + school = ?")
print(result3)
# Out:
# --- Word Analogies with GloVe ---
#
# king - man + woman = ?
# [('queen', 0.7698540687561035), ('monarch', 0.6843381524085999), ('throne', 0.6755736470222473), ('daughter', 0.6594556570053101), ('princess', 0.6520534157752991)]
#
# paris - france + india = ?
# [('delhi', 0.8654932975769043), ('mumbai', 0.7718895077705383), ('bombay', 0.7222235798835754), ('dhaka', 0.6891742944717407), ('calcutta', 0.6761991381645203)]
#
# doctor - hospital + school = ?
# [('teacher', 0.7837691307067871), ('taught', 0.7343935370445251), ('graduate', 0.7131244540214539), ('student', 0.6969646215438843), ('college', 0.6951188445091248)]
